# %%
Array= ['menus','menu/id','orders','orders/id','inventory','notifications','stores','loyality','pet']

# %%
methods =[
    ['post','get'],
    ['get','put','delete'],
    ['post','get'],
    ['get','put','delete'],
    ['post','get'],
    ['post','get'],
    ['post','get'],
    ['post','get'],
    ['get','put']
          ]

# %%
des = [
        ['Create a new menu','Finds all menus'],
        ['Returns a single menu','Update a menu in coffee shop','Deletes a menu'],
        ['Creates a new order','Finds all orders'],
        ['Returns a single order','Updates an order','Deletes an order'],
        ['Add a new Item to the inventory','Returns the inventory items'],
        ['Creates a new notification','Get all notifications'],
        ['Creates a new store','Finds all stores'],
        ['Creates a new loyalty program','Finds all loyalty programs'],
        ['','']  
      ]

# %%
summ = [
        ['','Finds all menus'],
        ['Find menu by ID','Updates a menu','Deletes a menu'],
        ['Creates a new order','Finds all orders'],
        ['Find order by ID','Updates an order','Deletes an order'],
        ['Add a new Item to the inventory','Updates an order','Returns the inventory items'],
        ['Creates a new notification',' Get all notifications'],
        ['Creates a new store',' Finds all stores'],
        ['Creates a new loyalty program','Finds all loyalty programs'],
        ['','']
      
         
      ]

# %%
empty_indices = []  # To store the indices of empty lists

# %%
for i in range(len(Array)):
    if (des[i][0]) == '' and (summ[i][0]) == '':
        empty_indices.append(i)

# %%
print(empty_indices)
# Out:
# [8]

# %%
for i in range(len(empty_indices)):
    for x in range(len(methods[i])):
        print(methods[empty_indices[i]][x])
# Out:
# get
# put

# %%
for i in range(len(empty_indices)):
    for x in range(len(methods[i])):
        
        if methods[empty_indices[i]][x] == 'get':
               
               des[empty_indices[i]][x] = 'get'+ ' ' + Array[empty_indices[i]]+ ' ' + 'details'

        elif methods[empty_indices[i]][x] == 'post':
               
               des[empty_indices[i]][x] = 'add'+ ' '  + Array[i] + ' ' + 'details'
               
        elif methods[empty_indices[i]][x] == 'put':
                            
                des[empty_indices[i]][x] = 'update'+ ' '  + Array[i] + ' ' + 'details'
                 
        elif methods[empty_indices[i]][x] == 'delete':
               
                des[empty_indices[i]][x] = 'delete'+ ' '  + Array[i] +  ' ' + 'details'
             
        else: 
             
                des[i][x] =Array[i]

# %%
print(des)
# Out:
# [['Create a new menu', 'Finds all menus'], ['Returns a single menu', 'Update a menu in coffee shop', 'Deletes a menu'], ['Creates a new order', 'Finds all orders'], ['Returns a single order', 'Updates an order', 'Deletes an order'], ['Add a new Item to the inventory', 'Returns the inventory items'], ['Creates a new notification', 'Get all notifications'], ['Creates a new store', 'Finds all stores'], ['Creates a new loyalty program', 'Finds all loyalty programs'], ['get pet details', 'update menus details']]

# %%
appenddocs = ['.'.join(sublist) for sublist in des]
appenddocs
# Out:
# ['Create a new menu.Finds all menus',
#  'Returns a single menu.Update a menu in coffee shop.Deletes a menu',
#  'Creates a new order.Finds all orders',
#  'Returns a single order.Updates an order.Deletes an order',
#  'Add a new Item to the inventory.Returns the inventory items',
#  'Creates a new notification.Get all notifications',
#  'Creates a new store.Finds all stores',
#  'Creates a new loyalty program.Finds all loyalty programs',
#  'get pet details.update menus details']

# %%
appenddocs_summery = ['.'.join(sublist) for sublist in summ]
appenddocs_summery
# Out:
# ['.Finds all menus',
#  'Find menu by ID.Updates a menu.Deletes a menu',
#  'Creates a new order.Finds all orders',
#  'Find order by ID.Updates an order.Deletes an order',
#  'Add a new Item to the inventory.Updates an order.Returns the inventory items',
#  'Creates a new notification. Get all notifications',
#  'Creates a new store. Finds all stores',
#  'Creates a new loyalty program.Finds all loyalty programs',
#  '.']

# %%
size_of_array = len(Array)
print("Size of Array:", size_of_array)
# Out:
# Size of Array: 9

# %%
full_doc=[]

# %%
for i in range(len(Array)):
    # Concatenate corresponding elements from first and second lists
    full_doc.append(Array[i]+'.' + appenddocs[i] +'.'+ appenddocs_summery[i])

# %%
for item in full_doc:
    print(item)
# Out:
# menus.Create a new menu.Finds all menus..Finds all menus
# menu/id.Returns a single menu.Update a menu in coffee shop.Deletes a menu.Find menu by ID.Updates a menu.Deletes a menu
# orders.Creates a new order.Finds all orders.Creates a new order.Finds all orders
# orders/id.Returns a single order.Updates an order.Deletes an order.Find order by ID.Updates an order.Deletes an order
# inventory.Add a new Item to the inventory.Returns the inventory items.Add a new Item to the inventory.Updates an order.Returns the inventory items
# notifications.Creates a new notification.Get all notifications.Creates a new notification. Get all notifications
# stores.Creates a new store.Finds all stores.Creates a new store. Finds all stores
# loyality.Creates a new loyalty program.Finds all loyalty programs.Creates a new loyalty program.Finds all loyalty programs
# pet.get pet details.update menus details..

# %%
from sentence_transformers import SentenceTransformer
# initialize sentence transformer model
model = SentenceTransformer('bert-base-nli-mean-tokens')
# create sentence embeddings
sentence_embeddings = model.encode(full_doc)
sentence_embeddings.shape
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# (9, 768)

# %%
import faiss

# %%
d = sentence_embeddings.shape[1]
index = faiss.IndexFlatIP(d)

# %%
index.is_trained
# Out:
# True

# %%
index.add(sentence_embeddings)

# %%
index.ntotal
# Out:
# 9

# %%
def Getting_relevent_path(sentence):
    k = 1
    xq = model.encode([sentence])

# %%
k = 1
sentence = "give code to Update all Menu details "
xq = model.encode([sentence])
xq
# Out:
# array([[-3.40921879e-01,  5.57511859e-03,  1.75078666e+00,
#          4.56925780e-02,  5.07452488e-01, -5.72071671e-01,
#          3.41474742e-01,  2.35833958e-01,  2.59582162e-01,
#         -5.96253276e-01, -6.94196701e-01,  1.15716588e+00,
#         -3.62002492e-01,  4.41907823e-01,  3.12192559e-01,
#          9.14837644e-02, -5.40355206e-01, -7.90066179e-03,
#         -4.99351352e-01,  2.32865229e-01, -6.59874499e-01,
#         -8.92471850e-01,  2.78881788e-01, -1.72747314e-01,
#          2.51984060e-01,  1.95821166e-01, -3.38660896e-01,
#          1.09522510e+00, -4.56417829e-01,  1.84641644e-01,
#         -9.76455808e-01, -1.76332712e-01,  9.07548487e-01,
#         -1.17351258e+00, -5.32070994e-01,  4.58228856e-01,
#          5.00560403e-01,  9.18434381e-01,  3.90475959e-01,
#          1.80277959e-01, -7.16459751e-01, -1.89741924e-01,
#          1.10489547e+00, -1.37661979e-01, -2.20235780e-01,
#         -3.82901877e-01, -1.27556443e+00,  2.53829360e-01,
#          3.78242403e-01,  1.72975674e-01, -3.44325900e-01,
#         -2.07915708e-01,  3.91628265e-01, -2.87236691e-01,
#          1.47773206e+00, -7.50392526e-02, -8.93627942e-01,
#          1.05186656e-01, -7.61803150e-01,  1.53650641e-01,
#         -1.13374138e+00,  1.81094319e-01, -4.04848427e-01,
#         -1.06267631e-01, -4.74451631e-01, -1.82743236e-01,
#         -7.97147334e-01, -8.96455497e-02, -1.30834907e-01,
#         -1.18122685e+00, -4.24917310e-01,  5.23467124e-01,
#          6.48919940e-01, -1.55991897e-01,  6.74313545e-01,
#          4.49483782e-01, -1.21029615e+00,  4.89942700e-01,
#         -3.24027091e-01, -6.47433519e-01, -3.65289569e-01,
#          7.13617861e-01,  1.06345102e-01,  2.57192820e-01,
#         -1.06784701e+00, -4.59950194e-02, -4.14530843e-01,
#         -7.99978137e-01, -6.02838516e-01,  4.61065441e-01,
#         -2.55145371e-01, -5.97227335e-01, -2.01823160e-01,
#         -5.01469016e-01,  4.91931438e-01,  1.43002998e-02]], dtype=float32)

# %%
import numpy as np
from numpy.linalg import norm

# %%
sentence_embeddings.shape
# Out:
# (9, 768)

# %%
sentence_embeddings[I[0][0]].shape
# Out:
# (768,)

# %%
xq.shape
# Out:
# (1, 768)

# %%
cosine = np.dot(sentence_embeddings[I[0]], xq[0]) / (np.linalg.norm(sentence_embeddings[I[0]]) * np.linalg.norm(xq[0]))
cosine_value = cosine[0]  # Extracting the value from the array


print("Cosine Similarity:", cosine_value)
# Out:
# Cosine Similarity: 0.80217314

# %%
#for x in range( int(len(I[0]))):  # Iterate over the range of size_i

Relevent_path = Array[I[0][0]]

print("This is the Relevent path :",Array[I[0][0]])
print(full_doc[I[0][0]])
# Out:
# This is the Relevent path : menus
# menus.Create a new menu.Finds all menus..Finds all menus

# %%
import csv

# %%
import pandas as pd
data= pd.read_csv("similarity_score.csv")
data
# Out:
#      Values
# 0  0.700000
# 1  0.650000
# 2  0.740000
# 3  0.632115
# 4  0.590863
# 5  0.557836
# 6  0.620836
# 7  0.620836
# 8  0.620836

# %%
text_data = data['Values']
text_data
# Out:
# 0    0.700000
# 1    0.650000
# 2    0.740000
# 3    0.632115
# 4    0.590863
# 5    0.557836
# 6    0.620836
# 7    0.620836
# 8    0.620836
# Name: Values, dtype: float64

# %%
row_count = len(data['Values'])

# %%
sum_value = 0
for i in range(row_count):
    sum_value = sum_value + float(text_data[i])

# %%
print(row_count,sum_value)
# Out:
# 9 5.733321869999999

# %%
predicting_similarity_score = float(sum_value) / row_count


print(predicting_similarity_score)
# Out:
# 0.6370357633333332

# %%
if cosine_value > predicting_similarity_score:
    print("This is the relevent path for Your Query :",Array[I[0][0]])
    #with open('similarity_score.csv','a', newline='') as file:
    #        cosine_str = str(cosine_value)
     #       file.write(cosine_str)

else:
    print("This is the relevent path for Your Query :",Array[I[0][0]])
    user_question = input("Is this what you expected [Yes/No] : ")

    if(user_question.lower() == 'yes'):
        print('hi')
    #    with open('similarity_score.csv','a', newline='') as file:
    #        cosine_str = str(cosine_value)
     #       file.write(cosine_str)
    
    else:
        user_path = input("What is the Relevent Path :")
# Out:
# This is the relevent path for Your Query : menus
