# %%
import json

# %% [markdown]
# Responece

# %%
def get_responses(w,path):
    if(w.lower()=='get'):

        responses = {
            '200': {
                'description': 'Successful retrieval',
                'content': {
                    'application/json': {
                        'example': {
                            'message': f'{path} retrieved successfully',
                            'data': {
                                
                            }
                        }
                    }
                }
            },
            '404': {
                'description': f'{path} not found',
                'content': {
                    'application/json': {
                        'example': {
                            'message': f'{path} not found'
                        }
                    }
                }
            },
            '500': {
                'description': 'Internal Server Error',
                'content': {
                    'application/json': {
                        'example': {
                            'message': 'Internal Server Error'
                        }
                    }
                }
            }
        }

    elif (w.lower()=='post'):
            
            responses = {
                '201': {
                    'description': 'Successful creation',
                    'content': {
                        'application/json': {
                            'example': {
                                'message':f'{path} created successfully'
                            }
                        }
                    }
                },
                '400': {
                    'description': 'Bad Request',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Invalid input data'
                            }
                        }
                    }
                },
                '500': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }


    elif (w.lower()=='put'):
            responses = {
                '200': {
                    'description': 'Successful operation',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} updated successfully'
                            }
                        }
                    }
                },
                '404': {
                    'description': f'{path} not found',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} not found'
                            }
                        }
                    }
                },
                '500': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }

    elif (w.lower()=='delete'):
        
            responses = {
                '204': {
                    'description': 'Successful deletion',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} deleted successfully'
                            }
                        }
                    }
                },
                '404': {
                    'description': 'Project not found',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} not found'
                            }
                        }
                    }
                },
                '500': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }

    else:
            
        responses = {
                
            }  
        
    return responses

# %%
def get_own_responses(w,path):
    if(w.lower()=='get'):

        n1 = input('Enter the HTTP Status Code for Successful retrieval :')
        n2 = input('Enter the HTTP Status Code for Path not found :')
        n3 = input('Enter the HTTP Status Code for Internal Server Error :')

        responses = {
            f'{n1}': {
                'description': 'Successful retrieval',
                'content': {
                    'application/json': {
                        'example': {
                            'message': f'{path} retrieved successfully',
                            'data': {
                                
                            }
                        }
                    }
                }
            },
            f'{n2}': {
                'description': f'{path} not found',
                'content': {
                    'application/json': {
                        'example': {
                            'message': f'{path} not found'
                        }
                    }
                }
            },
            f'{n3}': {
                'description': 'Internal Server Error',
                'content': {
                    'application/json': {
                        'example': {
                            'message': 'Internal Server Error'
                        }
                    }
                }
            }
        }

    elif (w.lower()=='post'):
            
            n1 = input('Enter the HTTP Status Code for Successful creation :')
            n2 = input('Enter the HTTP Status Code for Bad Request :')
            n3 = input('Enter the HTTP Status Code for Internal Server Error :')

            responses = {
                f'{n1}': {
                    'description': 'Successful creation',
                    'content': {
                        'application/json': {
                            'example': {
                                'message':f'{path} created successfully'
                            }
                        }
                    }
                },
                f'{n2}': {
                    'description': 'Bad Request',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Invalid input data'
                            }
                        }
                    }
                },
                f'{n3}': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }


    elif (w.lower()=='put'):

            n1 = input('Enter the HTTP Status Code for Successful operation :')
            n2 = input('Enter the HTTP Status Code for Path not found :')
            n3 = input('Enter the HTTP Status Code for Internal Server Error :')

            responses = {
                f'{n1}': {
                    'description': 'Successful operation',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} updated successfully'
                            }
                        }
                    }
                },
                f'{n2}': {
                    'description': f'{path} not found',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} not found'
                            }
                        }
                    }
                },
                f'{n3}': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }

    elif (w.lower()=='delete'):

            n1 = input('Enter the HTTP Status Code for Successful deletion :')
            n2 = input('Enter the HTTP Status Code for Path not found :')
            n3 = input('Enter the HTTP Status Code for Internal Server Error :')
        
            responses = {
                f'{n1}': {
                    'description': 'Successful deletion',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} deleted successfully'
                            }
                        }
                    }
                },
                f'{n2}': {
                    'description': 'Path not found',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': f'{path} not found'
                            }
                        }
                    }
                },
                f'{n3}': {
                    'description': 'Internal Server Error',
                    'content': {
                        'application/json': {
                            'example': {
                                'message': 'Internal Server Error'
                            }
                        }
                    }
                }
            }

    else:
            
        responses = {
                
            }  
        
    return responses
